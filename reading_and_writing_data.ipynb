# %% [markdown]
# <a href="https://colab.research.google.com/github/Manedk/AIArchitect/blob/main/reading_and_writing_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The `os` module
# "This module provides a portable way of using operating system dependent functionality" such as setting the current working directory and other methods for accessing the filesystem.
#
# https://docs.python.org/3/library/os.html

# %%
import os
# get current working directory
os.getcwd()
# Out:
# '/content'

# %%
os.chdir('img')  # change the working directory
os.listdir()  # execute the 'ls' command: list files and folders
# Out:
# ['python-logo.png',
#  'pycharmscreen.jpg',
#  'set-intersection.jpg',
#  'screenspyder.png',
#  'set-difference.jpg',
#  'set-union.jpg',
#  'SPYDERLOGO.png',
#  'set-symmetric-difference.jpg',
#  'pycharm.jpg',
#  'python_types.png']

# %%
os.chdir('..')  # go one directory up
os.listdir()
# Out:
# ['.config', 'img', '.ipynb_checkpoints', 'sample_data']

# %%
os.mkdir('test_dir')  # create a folder
os.listdir()
# Out:
# ['.config', 'img2', 'test_dir', 'img', '.ipynb_checkpoints', 'sample_data']

# %%
os.rename('test_dir', 'test_dir_new_name')  # rename a file or folder
os.listdir()
# Out:
# ['.config',
#  'img2',
#  'img',
#  'test_dir_new_name',
#  '.ipynb_checkpoints',
#  'sample_data']

# %%
os.removedirs('test_dir_new_name')  # delete a folder
os.listdir()
# Out:
# ['.config', 'img2', 'img', '.ipynb_checkpoints', 'sample_data']

# %% [markdown]
# # The `os.path` module
# "This module implements some useful functions on pathnames."
#
#
# "The path parameters can be passed as either strings, or bytes. Applications are encouraged to represent file names as (Unicode) character strings. Unfortunately, some file names may not be representable as strings on Unix, so applications that need to support arbitrary file names on Unix should use bytes objects to represent path names. Vice versa, using bytes objects cannot represent all file names on Windows (in the standard mbcs encoding), hence Windows applications should use string objects to access all files."
#
# https://docs.python.org/3/library/os.path.html
#
# Many methods accept *path-like objects* as input:
# "**path-like object:** An object representing a file system path. A path-like object is either a ```str``` or ```bytes``` object representing a path, or an object implementing the ```os.PathLike``` protocol. An object that supports the ```os.PathLike``` protocol can be converted to a ```str``` or ```bytes``` file system path by calling the ```os.fspath()``` function; ```os.fsdecode()``` and ```os.fsencode()``` can be used to guarantee a ```str``` or ```bytes``` result instead, respectively. Introduced by PEP 519."
#
# https://docs.python.org/3/glossary.html#term-path-like-object
#
# The following cells introduce some basic functions. See https://docs.python.org/3/library/os.path.html for a complete list.

# %%
# get the current working directory
current_dir = os.getcwd()
current_dir
# Out:
# '/content'

# %%
# check if a given object is a directory
os.path.isdir(current_dir)
# Out:
# True

# %%
# get the name of the directory
os.path.dirname(current_dir)
# Out:
# '/'

# %%
# combine a directory and a file name
current_file = os.path.join(current_dir,
                            '5_reading_and_writing_data.ipynb')
current_file
# Out:
# '/content/5_reading_and_writing_data.ipynb'

# %%
# check if a file exists
os.path.isfile(current_file)
# Out:
# False

# %%
# check if a directory exists
os.path.exists(os.path.join(current_dir, 'img'))
# Out:
# True

# %%
# Return the canonical path of the specified filename, eliminating any symbolic links
# encountered in the path (if they are supported by the operating system).
os.path.realpath('img')
# Out:
# '/content/img'

# %%
# Return a normalized absolutized version of the pathname path.
# On most platforms, this is equivalent to calling the function normpath() as follows:
# normpath(join(os.getcwd(), path)).
os.path.abspath('img')
# Out:
# '/content/img'

# %%
# Normalize a pathname by collapsing redundant separators and up-level references
# so that A//B, A/B/, A/./B and A/foo/../B all become A/B.
# This string manipulation may change the meaning of a path that contains symbolic links.
# On Windows, it converts forward slashes to backward slashes.
os.path.normpath('img')
# Out:
# 'img'

# %%
# get the basename of a directory
os.path.basename(current_dir)
# Out:
# 'content'

# %%
# split file into directory path and file name
os.path.split(current_file)
# Out:
# ('/content', '5_reading_and_writing_data.ipynb')

# %% [markdown]
# # The `with` statement
# "The with statement is used to wrap the execution of a block with methods defined by a context manager. This allows common `try…except…finally` usage patterns to be encapsulated for convenient reuse."
# The context manager defines `__exit__()` and `__enter__()` methods.
#
# After running the code in the with statement, a clean up process is executed. " The `with` statement guarantees that if the `__enter__()` method returns without an error, then `__exit__()` will always be called"
#
# This is often used when working with files as described in the next section.
#
# https://docs.python.org/3/reference/compound_stmts.html#the-with-statement
#
# https://www.python.org/dev/peps/pep-0343/

# %% [markdown]
# `with expression as variable:
#     with-block`

# %% [markdown]
# # Reading and Writing Files
# This section describes how to read and write files (e.g. CSV files). The full documentation of reading and writing files with Python 3 can be found at https://docs.python.org/3/tutorial/inputoutput.html.
#
#
# ## The `open()` method
# "`open()` returns a file object, and is most commonly used with two arguments: `open(filename, mode)`."
# Mode can be one of the following:
# * `'r'`: only reading (default)
# * `'w'`: only writing (overwrites existing file)
# * `'a'`: appending
# * `'r+'`: reading and writing
#
# Appending `'b'` to the mode "opens the file in *binary mode*" that "should be used for all files that don't contain text".
#
# https://docs.python.org/3/tutorial/inputoutput.html#reading-and-writing-files
#
#
# ## Methods of File Objects
#
# * `read(size)`: reads `size` bytes of the file (`size` by default reads the entire file into memory)
# * `readline()`: "reads a single line"
# * `write(string)`: :writes content of *string* to the file"
#
# https://docs.python.org/3/tutorial/inputoutput.html#methods-of-file-objects

# %%
filename = 'textfile.txt'

f = open(filename, 'w')
f.write('my first line\n')
f.write('second line')
f.close()  # close file and free up system resources

# %%
f = open(filename, 'r')
print(f.read())
f.close()
# Out:
# my first line
# second line

# %%
f = open(filename, 'r')
print(f.readline())
print(f.readline())
f.close()
# Out:
# my first line
#
# second line

# %%
f = open(filename, 'r')
for line in f:
    print(line)
f.close()
# Out:
# my first line
#
# second line

# %%
print()
print("hola")
# Out:
# hola

# %%
# Better: use the with statement to close the files automatically

with open(filename, 'r') as f:
    print(f.read())
# Out:
# my first line
# second line

# %% [markdown]
# ## The `json` Module
# * "The standard module called `json` can take Python data hierarchies, and convert them to string representations; this process is called *serializing*."
# * "Reconstructing the data from the string representation is called *deserializing*."
# * "Between *serializing* and *deserializing*, the string representing the object may have been stored in a file or data, or sent over a network connection to some distant machine."
#
# https://docs.python.org/3.3/tutorial/inputoutput.html#saving-structured-data-with-json

# %%
import json
# convert an object to its JSON string representation
x = [1, 'simple', 'list']
json.dumps(x)
# Out:
# '[1, "simple", "list"]'

# %%
# Serialize an object to a text file
jsonfile = 'jsonfile.json'
with open(jsonfile, 'w') as f:
    json.dump(x, f)

# %%
with open(jsonfile, 'r') as f:
    j = json.load(f)  # read a JSON file from disk
j
# Out:
# [1, 'simple', 'list']

# %%
|

# %% [markdown]
# ## Reading and Writing Files with pandas
# pandas can be used to read many formats such as CSV, Excel, JSON, Parquet, SQL, HDF, and many more. A full list of methods to read data is provided at http://pandas.pydata.org/pandas-docs/stable/reference/io.html.
#
# ### Writing CSV
#
# "Write object to a comma-separated values (csv) file."
#
# ```DataFrame.to_csv(path_or_buf=None, sep=', ', na_rep='', float_format=None, columns=None, header=True, index=True, index_label=None, mode='w', encoding=None, compression='infer', quoting=None, quotechar='"', line_terminator=None, chunksize=None, tupleize_cols=None, date_format=None, doublequote=True, escapechar=None, decimal='.')```
#
# "**Parameters:**
# * **path_or_buf:** *str or file handle, default ```None```.* File path or object, if ```None``` is provided the result is returned as a string. If a file object is passed it should be opened with ```newline=’‘```, disabling universal newlines.
# * **sep:** *str, default ‘,’.* String of length 1. Field delimiter for the output file.
# * **na_rep:** *str, default ‘’.* Missing data representation.
# * **float_format:** *str, default None.* Format string for floating point numbers.
# * **columns:** *sequence, optional.* Columns to write.
# * **header:** *bool or list of str, default ```True```.* Write out the column names. If a list of strings is given it is assumed to be aliases for the column names.
# * **index:** *bool, default ```True```.* Write row names (index).
# * ...
#
# **Returns: ```None``` or str.** If path_or_buf is ```None```, returns the resulting csv format as a string. Otherwise returns ```None```."
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html

# %%
import pandas as pd
# create a DataFrame
df = pd.DataFrame({'name': ['Raphael', 'Donatello'],
                   'mask': ['red', 'purple'],
                   'weapon': ['sai', 'bo staff']})
# write the DataFrame to disk
df.to_csv('turtles.csv', index=False)

# %%
df
# Out:
#         name    mask    weapon
# 0    Raphael     red       sai
# 1  Donatello  purple  bo staff

# %% [markdown]
# ### Reading CSV
#
# "Read a comma-separated values (csv) file into DataFrame. Also supports optionally iterating or breaking of the file into chunks. Additional help can be found in the online docs for IO Tools."
#
# ```pandas.read_csv(filepath_or_buffer, sep=', ', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)```
#
#
# "**Parameters:**
# * **filepath_or_buffer:** *str, path object, or file-like object*. Any valid string path is acceptable. The string could be a URL. Valid URL schemes include http, ftp, s3, and file. For file URLs, a host is expected. A local file could be: file://localhost/path/to/table.csv. If you want to pass in a path object, pandas accepts either ```pathlib.Path``` or ```py._path.local.LocalPath```. By file-like object, we refer to objects with a ```read()``` method, such as a file handler (e.g. via builtin open function) or ```StringIO```.
# * **sep:** *str, default ‘,’*. Delimiter to use. If sep is ```None```, the C engine cannot automatically detect the separator, but the Python parsing engine can, meaning the latter will be used and automatically detect the separator by Python’s builtin sniffer tool, ```csv.Sniffer```. In addition, separators longer than 1 character and different from ```'\s+'``` will be interpreted as regular expressions and will also force the use of the Python parsing engine. Note that regex delimiters are prone to ignoring quoted data. Regex example: ```'\r\t'```.
# * **delimiter:** *str, default ```None```*. Alias for sep.
# * ...
#
# **Returns: DataFrame or TextParser**. A comma-separated values (csv) file is returned as two-dimensional data structure with labeled axes."
#
# http://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html

# %%
# read a csv file from disk
pd.read_csv('turtles.csv')
# Out:
#         name    mask    weapon
# 0    Raphael     red       sai
# 1  Donatello  purple  bo staff

# %% [markdown]
# ### Writing Excel
#
# "Write object to an Excel sheet. To write a single object to an Excel *.xlsx* file it is only necessary to specify a target file name. To write to multiple sheets it is necessary to create an ```ExcelWriter``` object with a target file name, and specify a sheet in the file to write to. Multiple sheets may be written to by specifying unique ```sheet_name```. With all data written to the file it is necessary to save the changes. Note that creating an ```ExcelWriter``` object with a file name that already exists will result in the contents of the existing file being erased."
#
# ```DataFrame.to_excel(excel_writer, sheet_name='Sheet1', na_rep='', float_format=None, columns=None, header=True, index=True, index_label=None, startrow=0, startcol=0, engine=None, merge_cells=True, encoding=None, inf_rep='inf', verbose=True, freeze_panes=None)```
#
# "**Parameters:**
# * **excel_writer:** *str or ```ExcelWriter``` object*. File path or existing ```ExcelWriter```.
# * **sheet_name:** *str, default ‘Sheet1’*. Name of sheet which will contain DataFrame.
# * **na_rep:** *str, default ‘’*. Missing data representation.
# * **float_format:** *str, optional*. Format string for floating point numbers. For example ```float_format="%.2f"``` will format 0.1234 to 0.12.
# * **columns:** *sequence or list of str, optional*. Columns to write.
# * **header:** *bool or list of str, default True*. Write out the column names. If a list of string is given it is assumed to be aliases for the column names.
# * **index:** *bool, default ```True```*. Write row names (index).
# * **index_label:** *str or sequence, optional*. Column label for index column(s) if desired. If not specified, and header and index are ```True```, then the index names are used. A sequence should be given if the DataFrame uses ```MultiIndex```.
# * ..."
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_excel.html

# %%
# write DataFrame in .xlsx format to disk
df.to_excel('turtles.xlsx')

# %% [markdown]
# ### Reading Excel
#
# "Read an Excel file into a pandas DataFrame.
#
# Support both *xls* and *xlsx* file extensions from a local filesystem or URL. Support an option to read a single sheet or a list of sheets."
#
# ```pandas.read_excel(io, sheet_name=0, header=0, names=None, index_col=None, parse_cols=None, usecols=None, squeeze=False, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, verbose=False, parse_dates=False, date_parser=None, thousands=None, comment=None, skip_footer=0, skipfooter=0, convert_float=True, mangle_dupe_cols=True, **kwds)```
#
# "**Parameters:**
# * **io:** *str, file descriptor, pathlib.Path, ExcelFile or xlrd.Book*. The string could be a URL. Valid URL schemes include http, ftp, s3, gcs, and file. For file URLs, a host is expected. For instance, a local file could be /path/to/workbook.xlsx.
# * **sheet_name:** *str, int, list, or ```None```, default 0*. Strings are used for sheet names. Integers are used in zero-indexed sheet positions. Lists of strings/integers are used to request multiple sheets. Specify ```None``` to get all sheets. Available cases:
#   * Defaults to 0: 1st sheet as a DataFrame
#   * 1: 2nd sheet as a DataFrame
#   * "Sheet1": Load sheet with name “Sheet1”
#   * [0, 1, "Sheet5"]: Load first, second and sheet named “Sheet5” as a dict of DataFrame
#   * ```None```: All sheets.
# * **header:** *int, list of int, default 0*. Row (0-indexed) to use for the column labels of the parsed DataFrame. If a list of integers is passed those row positions will be combined into a ```MultiIndex```. Use ```None``` if there is no header.
# * **names:** *array-like, default ```None```*. List of column names to use. If file contains no header row, then you should explicitly pass ```header=None```.
# * ...
#
# **Returns: DataFrame or dict of DataFrames**. DataFrame from the passed in Excel file. See notes in ```sheet_name``` argument for more information on when a dict of DataFrames is returned."
# `
# http://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html

# %%
{"Hoja 1": pd.DataFrame(), "Hoja 2": pd.DataFrame()}
# Out:
# {'Hoja 1': Empty DataFrame
#  Columns: []
#  Index: [], 'Hoja 2': Empty DataFrame
#  Columns: []
#  Index: []}

# %%
#conda install -c anaconda xlrd

# %%
# read excel file from disk
pd.read_excel('turtles.xlsx', index_col=0)
# Out:
#         name    mask    weapon
# 0    Raphael     red       sai
# 1  Donatello  purple  bo staff

# %%
import requests
import json
response = json.loads(requests.get("https://webhooks.mongodb-realm.com/api/client/v2.0/app/applicationvital-usvhp/service/Vital_servicesAPI/incoming_webhook/VitalAPIwebhook").text)

# %%
response
# Out:
# [{'Area': 'CEYE',
#   'Cliente': 'VISION LASER',
#   'Equipo': 'AUTOCLAVE',
#   'Fecha': '11/01/21',
#   'Folio': '1826',
#   'Marca': 'SCICAN',
#   'Modelo': 'STATIM 5000',
#   'No_Serie': '5105AL0001',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb885f'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'CME-HOSP-13',
#   'Equipo': 'CAMA ELECTRICA',
#   'Fecha': '25/01/21',
#   'Folio': '1843-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1BUZFN0ARjQWxsiSvdSC8AtIXEmHemZ79/view?usp=sharing',
#   'Marca': 'HILL ROM',
#   'Modelo': 'ADVANTA',
#   'No_Serie': 'E2051B8238',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8870'}},
#  {'Area': 'QUIROFANO 3',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'MQ-QX-03',
#   'Equipo': 'MESA QUIRURGICA',
#   'Fecha': '06/02/21',
#   'Folio': '1880-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1aOFze4p3-Vdw9jrwYp2WmC0ibvqRlqem/view?usp=sharing',
#   'Marca': 'AMSCO',
#   'Modelo': '2080',
#   'No_Serie': '405691075',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8895'}},
#  {'Area': 'RESGUARDO BIOMEDICA',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'MSV-RB-02',
#   'Equipo': 'MSV',
#   'Fecha': '29/02/2021',
#   'Folio': '1854-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1eNoCERm4DZLK9UDyn_79qcE6TJQpMdAD/view?usp=sharing',
#   'Marca': 'WELCH ALLYN',
#   'Modelo': 'ATLAS',
#   'No_Serie': '62121214',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb887b'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'DESFIBRILADOR',
#   'Fecha': '27/01/21',
#   'Folio': '1849',
#   'Marca': 'PHYSIOCONTROL',
#   'Modelo': 'LIFEPAK 9P',
#   'No_Serie': '15597',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8876'}},
#  {'Area': 'N/A',
#   'Cliente': 'DR. ENRIQUE HAMBACUAN',
#   'Equipo': 'COMPRESOR',
#   'Fecha': '02/02/21',
#   'Folio': '1863',
#   'Marca': 'CTC',
#   'Modelo': 'VASOPRESS 500',
#   'No_Serie': '3950335992',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8884'}},
#  {'Area': 'NA',
#   'Cliente': 'TORRES CORZO ',
#   'Equipo': 'CONCENTRADOR',
#   'Fecha': '09/02/21',
#   'Folio': '1891',
#   'Marca': 'PHILIPS',
#   'Modelo': 'EVERFLO',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88a0'}},
#  {'Area': 'NA',
#   'Cliente': 'Bárbara Melo',
#   'Equipo': 'BOMBA DE INFUSION',
#   'Fecha': '19/02/21',
#   'Folio': '1910',
#   'Marca': 'ABBOTT',
#   'Modelo': 'LIFECARE 5000',
#   'No_Serie': '96370813',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88b3'}},
#  {'Area': 'BRAQUITERAPIA',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'ASPIRADOR',
#   'Fecha': '25/02/21',
#   'Folio': '1922',
#   'Marca': 'IUMED',
#   'Modelo': 'N33V-G',
#   'No_Serie': '996108A',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88c2'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'MONITOR DE SIGNOS VITALES',
#   'Fecha': '10/03/21',
#   'Folio': '1944',
#   'Marca': 'CONTEC',
#   'Modelo': 'CMS8000',
#   'No_Serie': '17110400056',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88db'}},
#  {'Area': 'QUIROFANO 2 ',
#   'Cliente': 'SMA HEALTH SERVICES ',
#   'Equipo': 'MAQUINA DE ANESTESIA',
#   'Fecha': '26/03/21',
#   'Folio': '1964-SMA',
#   'Marca': 'DATEX OHMEDA',
#   'Modelo': 'MODULUS SE',
#   'No_Serie': 'AMFD00254',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88ef'}},
#  {'Area': 'RECUPERACION',
#   'Cliente': 'SMA HEALTH SERVICES ',
#   'Equipo': 'CONCENTRADOR',
#   'Fecha': '26/03/21',
#   'Folio': '1972-SMA',
#   'Marca': 'INVACARE',
#   'Modelo': 'IRC5P02',
#   'No_Serie': '08CF014433',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88f7'}},
#  {'Cliente': 'VIDA MEDICA',
#   'Equipo': 'GRABADOR',
#   'Fecha': '29/03/21',
#   'Folio': '1976',
#   'Marca': 'STRYKER',
#   'Modelo': 'SDC HD',
#   'No_Serie': '07H060374',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88fb'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'MSV',
#   'Fecha': '07/04/21',
#   'Folio': '1983',
#   'Marca': 'CONTEC',
#   'Modelo': 'CMS8000VET',
#   'No_Serie': '17080700057',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8902'}},
#  {'Area': 'N/A',
#   'Cliente': 'ARTRO HOPE',
#   'Equipo': 'UNIDAD DE CONTROL ENDOSCOPIA',
#   'Fecha': '04/05/21',
#   'Folio': '2028',
#   'Marca': 'DYONICS',
#   'Modelo': 'EP-1',
#   'No_Serie': '3778',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb892f'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Equipo': 'MONITOR DE SIGNOS VITALES',
#   'Fecha': '12/05/21',
#   'Folio': '2049-CP',
#   'Marca': 'DATEX OHMEDA',
#   'Modelo': 'CARDIOCAP S/5',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8944'}},
#  {'Area': 'CONSULTORIO',
#   'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'BASCULA',
#   'Fecha': '14/05/21',
#   'Folio': '2057',
#   'Marca': 'BAME',
#   'Modelo': '420',
#   'No_Serie': '993-21',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb894c'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'CAMT-HOSP-03',
#   'Equipo': 'CAMILLA DE TRASLADO',
#   'Fecha': '17/05/21',
#   'Folio': '2064-CP',
#   'Marca': 'MIDMARK',
#   'Modelo': 'K520-001',
#   'No_Serie': 'TAV007688',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8953'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'GUARPA',
#   'Equipo': 'MSV',
#   'Fecha': '19/05/21',
#   'Folio': '2077',
#   'Marca': 'NELLCOR',
#   'Modelo': 'OXIMAX',
#   'No_Serie': '23309060003',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8960'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Equipo': 'LIGASURE',
#   'Fecha': '20/05/21',
#   'Folio': '2081-CP',
#   'Marca': 'VALLEYLAB',
#   'Modelo': 'LS10',
#   'No_Serie': 'L18J1576GX',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8964'}},
#  {'Area': 'CONSULTORIO 1',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Equipo': 'BASCULA',
#   'Fecha': '25/05/21',
#   'Folio': '2096-CP',
#   'Marca': 'SECA',
#   'Modelo': '700',
#   'No_Serie': '5.70E+13',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8973'}},
#  {'Area': 'CONSULTORIO',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'LAMPARA DE EXAMINACION',
#   'Fecha': '01/06/21',
#   'Folio': '2110',
#   'Marca': 'WELLCH ALLYN',
#   'Modelo': 'LS-135',
#   'No_Serie': '611',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8981'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'CAMT-HOSP-06',
#   'Equipo': 'CAMILLA DE TRASLADO',
#   'Fecha': '14/06/21',
#   'Folio': '2131-CP',
#   'Marca': 'STRIKER.',
#   'Modelo': 'BIG WHEEL',
#   'No_Serie': '512069877',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8996'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'DR. ARRIAGA',
#   'Equipo': 'BOMBA DE INFUSION',
#   'Fecha': '24/06/21',
#   'Folio': '2145',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89a4'}},
#  {'Area': 'NA',
#   'Cliente': 'EMPHI',
#   'Equipo': 'MSV',
#   'Fecha': '28/06/21',
#   'Folio': '2153',
#   'Marca': 'ECOMED',
#   'Modelo': 'EPM-80 iPLUS',
#   'No_Serie': 'NA',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89ac'}},
#  {'Area': 'QUIMIOTERAPIA',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'BAUMANOMETRO',
#   'Fecha': '17/07/21',
#   'Folio': '2169',
#   'Marca': 'WELCHALLYN',
#   'Modelo': '297',
#   'No_Serie': '91029171831',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89bc'}},
#  {'Area': 'QUIROFANO 2',
#   'Cliente': 'GUARPA',
#   'Equipo': 'CALENTADOR',
#   'Fecha': '21/07/21',
#   'Folio': '2180',
#   'Marca': 'NELLCOR',
#   'Modelo': 'WARM TOUCH',
#   'No_Serie': 'CI0610J036',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89c7'}},
#  {'Cliente': 'EMPHI',
#   'Equipo': 'BOMBA DE INFUSION',
#   'Fecha': '22/07/21',
#   'Folio': '2186',
#   'Marca': 'HOSPIRA',
#   'Modelo': 'LIFECARE 5000',
#   'No_Serie': '96370156',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89cd'}},
#  {'Area': 'RECUPERACION',
#   'Cliente': 'DR LUIS RODRIGUEZ',
#   'Equipo': 'CAMA ELECTRICA',
#   'Fecha': '27/07/21',
#   'Folio': '2197',
#   'Marca': 'HILL ROM',
#   'Modelo': 'ADVANCE SERIES BED',
#   'No_Serie': '1105-23G55-A',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89d5'}},
#  {'Area': 'CONSULTORIO 3',
#   'Cliente': 'MENDOZA BARBOSA',
#   'Equipo': 'LAMPARA DE HENDIDURA',
#   'Fecha': '27/07/21',
#   'Folio': '2207',
#   'Marca': 'CSO',
#   'Modelo': 'SL 9900',
#   'No_Serie': '15090060',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89df'}},
#  {'Cliente': 'AMBULANCIAS LIFE',
#   'Folio': '1847',
#   '_id': {'$oid': '610750456fcd07beffdb8874'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'MESA QUIRURGICA',
#   'Fecha': '26/01/21',
#   'Folio': '1848',
#   'Marca': 'SKYTRON',
#   'Modelo': '6500',
#   'No_Serie': '6500020',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8875'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'Fundación Mendoza Barbosa.\xa0',
#   'Equipo': 'ASPIRADOR',
#   'Fecha': '03/02/21',
#   'Folio': '1871',
#   'Marca': 'SIN MARCA',
#   'Modelo': 'SIN MODELO',
#   'No_Serie': 'SIN NS (092)',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb888c'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'Fundación Mendoza Barbosa.',
#   'Equipo': 'ASPIRADOR',
#   'Fecha': '04/02/21',
#   'Folio': '1874',
#   'Marca': 'SIN MARCA',
#   'Modelo': 'SIN MODELO',
#   'No_Serie': 'SIN NS (092)',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb888f'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'Fundación Mendoza Barbosa',
#   'Equipo': 'MSV',
#   'Fecha': '08/02/21',
#   'Folio': '1882',
#   'Marca': 'DINAMAP',
#   'Modelo': 'PRO 400V2',
#   'No_Serie': 'AAX05080037SA',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8897'}},
#  {'Area': 'QUIROFANO 1',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'MQ-QX-01',
#   'Equipo': 'MESA QUIRURGICA',
#   'Fecha': '09/02/21',
#   'Folio': '1888-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1y9xJ21P6VtGuE4TOhVRiIF7EUtzeup37/view?usp=sharing',
#   'Marca': 'AMSCO',
#   'Modelo': '2080',
#   'No_Serie': '417183050',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb889d'}},
#  {'Area': 'QUIROFANO RECU',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'QXR-DES-01',
#   'Equipo': 'DESFIBRILADOR',
#   'Fecha': '11/02/21',
#   'Folio': '1896-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1aruYu582L7C7Ay6E_b3aplJZ9diTw-ff/view?usp=sharing',
#   'Marca': 'PHYSIO-CONTROL',
#   'Modelo': 'LIFEPAK 9',
#   'No_Serie': '20806',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88a5'}},
#  {'Area': 'CUARTO IODO',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'CAMA ELECTRICA',
#   'Fecha': '16/02/21',
#   'Folio': '1904',
#   'Marca': 'HILL-ROM',
#   'Modelo': 'CAREASSIST',
#   'No_Serie': 'HRP000322009',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88ad'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'MESA QUIRURGICA',
#   'Fecha': '19/02/21',
#   'Folio': '1912',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88b5'}},
#  {'Area': 'NA',
#   'Cliente': 'BERRY GLOBAL',
#   'Equipo': 'CONCENTRADOR DE OXIGENO',
#   'Fecha': '26/02/21',
#   'Folio': '1923',
#   'Marca': 'PHILIPS',
#   'Modelo': 'EVERFLO',
#   'No_Serie': '230887',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88c3'}},
#  {'Area': 'NA',
#   'Cliente': 'OSWALDO MORALES',
#   'Equipo': 'CONCENTRADOR DE O2',
#   'Fecha': '12/03/21',
#   'Folio': '1945',
#   'Marca': 'PHILLIPS',
#   'Modelo': 'RESPIRONICS',
#   'No_Serie': '161289',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88dc'}},
#  {'Cliente': 'GUARPA',
#   'Equipo': 'CAMILLA',
#   'Fecha': '17/03/21',
#   'Folio': '1949',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88e0'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'CAMT-HOSP-06',
#   'Equipo': 'CAMILLA DE TRASLADO',
#   'Fecha': '24/03/21',
#   'Folio': '1960-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1Yk0jmFJcQLoiknRg185AY_hRggoKqnHc/view?usp=sharing',
#   'Marca': 'STRYKER',
#   'Modelo': 'BIGWHEEL',
#   'No_Serie': '512069877',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88eb'}},
#  {'Area': 'QUIROFANO 1',
#   'Cliente': 'SMA HEALTH SERVICES ',
#   'Equipo': 'EQS',
#   'Fecha': '26/03/21',
#   'Folio': '1969-SMA',
#   'Marca': 'VALLEY LAB',
#   'Modelo': 'FORCE EZ',
#   'No_Serie': 'F0H4360B',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88f4'}},
#  {'Area': 'QUIRIFANO 1',
#   'Cliente': 'SMA HEALTH SERVICES ',
#   'Equipo': 'MAQUINA DE ANESTESIA',
#   'Fecha': '26/03/21',
#   'Folio': '1970-SMA',
#   'Marca': 'PENLON',
#   'Modelo': 'SP2',
#   'No_Serie': 'SP20310123',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88f6'}},
#  {'Cliente': 'GUARPA',
#   'Equipo': 'ELECTROCAUTERIO ',
#   'Fecha': '03/05/21',
#   'Folio': '2025',
#   'Marca': 'VALLEYLAB',
#   'Modelo': 'SURGISTAT B',
#   'No_Serie': 'A5L6691B-20',
#   'Servicio': 'PREVENTIVO/CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb892c'}},
#  {'Area': 'CEYE',
#   'Cliente': 'GUARPA',
#   'Equipo': 'AUTOCLAVE',
#   'Fecha': '03/05/21',
#   'Folio': '2027',
#   'Servicio': 'PREVENTIVO/CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb892e'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'AXIOMA',
#   'Equipo': 'ELECTROCAUTERIO',
#   'Fecha': '13/05/21',
#   'Folio': '2051',
#   'Marca': 'CONMED',
#   'Modelo': 'EXCALIBUR PLUS PC',
#   'No_Serie': '01CGE 029',
#   'Servicio': 'PREVENTIVO/DIAGNOSTICO',
#   '_id': {'$oid': '610750456fcd07beffdb8946'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'BI-MO-11',
#   'Equipo': 'BOMBA DE INFUSION',
#   'Fecha': '14/05/21',
#   'Folio': '2056-CP',
#   'Marca': 'HOSPIRA',
#   'Modelo': 'LIFECARE 5000',
#   'No_Serie': '96374797',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb894b'}},
#  {'Area': 'UCIN',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'TC-TC-01',
#   'Equipo': 'TOCOCARDIOGRAFO',
#   'Fecha': '17/052021',
#   'Folio': '2066-CP',
#   'Marca': 'CHOROMETRICS',
#   'Modelo': '150',
#   'No_Serie': '3300604',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8955'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'GUARPA',
#   'Equipo': 'MSV',
#   'Fecha': '19/05/21',
#   'Folio': '2078',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8961'}},
#  {'Area': 'URGENCIAS',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Equipo': 'BASCULA',
#   'Fecha': '25/05/21',
#   'Folio': '2094-CP',
#   'Marca': 'SECA',
#   'Modelo': '700',
#   'No_Serie': '5.70E+12',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8971'}},
#  {'Area': 'RESGUARDO',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'QX-KRT-01',
#   'Equipo': 'MEDICAL CART',
#   'Fecha': '01/06/21',
#   'Folio': '2116-CP',
#   'Marca': 'STRYKER',
#   'Modelo': '240-099-020',
#   'No_Serie': '070605AG009',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8987'}},
#  {'Area': 'HOSPITALIZACIÓN',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'CAMILLA',
#   'Fecha': '05/06/21',
#   'Folio': '2122',
#   'Marca': 'STRYKER',
#   'Modelo': 'STRETCHER',
#   'No_Serie': '910032700',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb898d'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'DR. ARRIAGA',
#   'Equipo': 'LAMPARA QUIRUGICA',
#   'Fecha': '24/06/21',
#   'Folio': '2138',
#   'Marca': 'PANALEX',
#   'Modelo': '1',
#   'No_Serie': 'G7489',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb899d'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'CAMILLA',
#   'Fecha': '10/07/21',
#   'Folio': '2167',
#   'Marca': 'STRYKER',
#   'Modelo': '0737 STRETCHER',
#   'No_Serie': '910032699',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89ba'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'CAMILLA',
#   'Fecha': '10/07/21',
#   'Folio': '2168',
#   'Marca': 'STRYKER',
#   'Modelo': '0737 STRETCHER',
#   'No_Serie': '910032698',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89bb'}},
#  {'Area': 'QUIROFANO 1',
#   'Cliente': 'GUARPA',
#   'Equipo': 'ASPIRADOR',
#   'Fecha': '09/02/21',
#   'Folio': '1890',
#   'Marca': 'ZERO',
#   'Modelo': 'CENTURION',
#   'No_Serie': '595',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb889f'}},
#  {'Area': 'CUARTO IODO',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'CAMA ELECTRICA',
#   'Fecha': '18/02/21',
#   'Folio': '1909',
#   'Marca': 'HILL-ROM',
#   'Modelo': 'CAREASSIST',
#   'No_Serie': 'HRP000330872',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88b2'}},
#  {'Area': 'AMBULATORIA',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'CAMT-AMB-01',
#   'Equipo': 'CAMILLA DE TRASLADO',
#   'Fecha': '24/02/21',
#   'Folio': '1918-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1MQZswxFynbNk-Z7zCsqk7ksV9WDNe2IW/view?usp=sharing',
#   'Marca': 'HILL ROM',
#   'Modelo': 'P8000',
#   'No_Serie': 'G217AN0058',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88bb'}},
#  {'Area': 'UCI',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'CMT-UCI-02',
#   'Equipo': 'CAMA DE TERAPIA',
#   'Fecha': '24/02/21',
#   'Folio': '1920-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1TlxG3_tX0o6Gw6xXMxWGB0EtJqphpGQK/view?usp=sharing',
#   'Marca': 'HILL ROM',
#   'Modelo': 'SPO2RT',
#   'No_Serie': '2819',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88bd'}},
#  {'Area': 'RECUPERACION',
#   'Cliente': 'GUARPA',
#   'Equipo': 'DESFIBRILADOR',
#   'Fecha': '20/02/21',
#   'Folio': '1913',
#   'Marca': 'ZOLL',
#   'Modelo': 'M-SERIES',
#   'No_Serie': 'T06I83889',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88b6'}},
#  {'Area': 'SALA DE LABOR',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'CT-SL-01',
#   'Equipo': 'CUNA TERMICA',
#   'Fecha': '22/02/21',
#   'Folio': '1915-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1MQZswxFynbNk-Z7zCsqk7ksV9WDNe2IW/view?usp=sharing',
#   'Marca': 'AIR SHIELDS VICKERS',
#   'Modelo': 'PM-78',
#   'No_Serie': 'QM8534',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88b8'}},
#  {'Cliente': 'VISION LASER',
#   'Folio': '1926',
#   '_id': {'$oid': '610750456fcd07beffdb88c6'}},
#  {'Area': 'URGENCIAS',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'DES-URG-01',
#   'Equipo': 'DESFIBRILADOR',
#   'Fecha': '03/03/21',
#   'Folio': '1930-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1L8HBwovQv18NHnCnJzt3CRuhkBfRG2AE/view?usp=sharing',
#   'Marca': 'ZOLL ',
#   'Modelo': 'M SERIES ',
#   'No_Serie': 'T99J05619',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88cd'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'DES-HOSP-01',
#   'Equipo': 'DESFIBRILADOR',
#   'Fecha': '01/03/21',
#   'Folio': '1926-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/11il8DLmqaU7_rkWC_9s99dqBelp5uwKn/view?usp=sharing',
#   'Marca': 'ZOLL ',
#   'Modelo': 'M SERIES CCT',
#   'No_Serie': 'T08A98502',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88c9'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'ESPECIALIDADES MEDICAS DE RIO VERDE',
#   'Equipo': 'MSV',
#   'Fecha': '23/04/21',
#   'Folio': '2013',
#   'Marca': 'DATASCOPE',
#   'Modelo': 'PASSPORT',
#   'No_Serie': 'P57702-C8',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8920'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'ESPECIALIDADES MEDICAS DE RIO VERDE',
#   'Equipo': 'DESFIBTRILADOR',
#   'Fecha': '23/04/21',
#   'Folio': '2014',
#   'Marca': 'PHISIO CONTROL',
#   'Modelo': 'LIFEPAK 9',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8921'}},
#  {'Equipo': 'CAMINADORA',
#   'Fecha': '01/03/21',
#   'Folio': '1927',
#   'Marca': 'IMAGE',
#   'Modelo': 'IMTL31504',
#   'No_Serie': 'ND',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88ca'}},
#  {'Cliente': 'SERGIO SOLANO',
#   'Equipo': 'CAMILLA',
#   'Fecha': '05/03/21',
#   'Folio': '1934',
#   'Marca': 'MIDMARK',
#   'Modelo': 'K545-001',
#   'No_Serie': 'TEX002431',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88d1'}},
#  {'Area': 'CUARTO IODO 1',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'CAMA ELECTRICA',
#   'Fecha': '06/03/21',
#   'Folio': '1937',
#   'Marca': 'STRYKER',
#   'Modelo': 'FL28C',
#   'No_Serie': 'R22751',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88d4'}},
#  {'Area': 'NA',
#   'Cliente': 'OLIMED',
#   'Equipo': 'CUNA TERMICA',
#   'Fecha': '29/04/21',
#   'Folio': '2019',
#   'Marca': 'OHMEDA',
#   'Modelo': '3300',
#   'No_Serie': 'AANQ00527',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8926'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'ASPIRADOR',
#   'Fecha': '09/03/21',
#   'Folio': '1939',
#   'Marca': 'BERKELEY',
#   'Modelo': 'VC - II',
#   'No_Serie': '2583',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88d6'}},
#  {'Area': 'CONSULTORIO',
#   'Cliente': 'DR ARRIAGA GAMBOA',
#   'Equipo': 'MESA DE EXPLORACION GINECOLOGICA',
#   'Fecha': '13/05/21',
#   'Folio': '2050',
#   'Marca': 'N/A',
#   'Modelo': 'N/A',
#   'No_Serie': 'N/A',
#   'Servicio': 'PREVENTIVO/CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8945'}},
#  {'Cliente': 'BIOS',
#   'Equipo': 'BOMBA DE INFUSION',
#   'Fecha': '15/04/21',
#   'Folio': '1990',
#   'Marca': 'HOSPIRA',
#   'Modelo': 'PLUM A+',
#   'No_Serie': '17671222',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8909'}},
#  {'Area': 'CONSULTORIO',
#   'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'BASCULA',
#   'Fecha': '14/05/21',
#   'Folio': '2059',
#   'Marca': 'BAME',
#   'Modelo': '420',
#   'No_Serie': '991-21',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb894e'}},
#  {'Cliente': 'BIOS',
#   'Equipo': 'BOMBA DE INFUSION',
#   'Fecha': '15/04/21',
#   'Folio': '1991',
#   'Marca': 'HOSPIRA',
#   'Modelo': 'PLUM A+',
#   'No_Serie': '16114486',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb890a'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Equipo': 'BISTURI ARMONICO',
#   'Fecha': '20/05/21',
#   'Folio': '2080-CP',
#   'Marca': 'ETHICON',
#   'Modelo': 'G11',
#   'No_Serie': '1111319288',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8963'}},
#  {'Area': 'N/A',
#   'Cliente': 'OLIMED',
#   'Equipo': 'INCUBADORA',
#   'Fecha': '21/04/21',
#   'Folio': '2004',
#   'Marca': 'HILL ROM',
#   'Modelo': 'C2HS-1',
#   'No_Serie': 'TN04322',
#   'Servicio': 'PREVENTIVO/CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8917'}},
#  {'Cliente': 'CLINICA DEL PARQUE',
#   'Fecha': '20/05/21',
#   'Folio': '2083-CP',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8966'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Equipo': 'BASCULA',
#   'Fecha': '21/05/21',
#   'Folio': '2090-CP',
#   'Marca': 'SECA',
#   'Modelo': '700',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb896d'}},
#  {'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'CAMILLA DE TRASLADO',
#   'Fecha': '24/04/21',
#   'Folio': '2016',
#   'Marca': 'MEDSTAR',
#   'Servicio': 'PREVENTIVO/CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8923'}},
#  {'Area': 'DR',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Equipo': 'LASER',
#   'Fecha': '25/05/21',
#   'Folio': '2095-CP',
#   'Marca': 'LUMENIS',
#   'Modelo': 'SA3501000',
#   'No_Serie': '015-09162',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8972'}},
#  {'Area': 'NA',
#   'Cliente': 'GUARPA',
#   'Equipo': 'COMPRESOR VASCULAR',
#   'Fecha': '30/04/21',
#   'Folio': '2020',
#   'Marca': 'KENDALL',
#   'Modelo': 'SCD SEQUEL',
#   'No_Serie': 'ES38577',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8927'}},
#  {'Area': 'NA',
#   'Cliente': 'OLIMED',
#   'Equipo': 'INCUBADORA',
#   'Fecha': '25/05/21',
#   'Folio': '2098',
#   'Link_Drive': 'SE CORRIGE EL FOLIO 2095 ',
#   'Marca': 'HILL ROM',
#   'Modelo': 'C550H-1',
#   'No_Serie': 'QM00464',
#   'Servicio': 'DICTAMEN',
#   '_id': {'$oid': '610750456fcd07beffdb8975'}},
#  {'Area': 'AMBULATORIA',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'CAMT-AMB-01',
#   'Equipo': 'CAMILLA DE TRASLADO',
#   'Fecha': '07/05/21',
#   'Folio': '2037-CP',
#   'Marca': 'HILL ROM',
#   'Modelo': 'P8000',
#   'No_Serie': 'G217AN0058',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8938'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'MAQUINA DE ANESTESIA',
#   'Fecha': '29/05/21',
#   'Folio': '2102',
#   'Marca': 'OHMEDA',
#   'Modelo': 'SM',
#   'No_Serie': 'AMAY1006',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8979'}},
#  {'Area': 'CUNEROS',
#   'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'INCUBADORA',
#   'Fecha': '10/05/21',
#   'Folio': '2046',
#   'Marca': 'AIRSHIELDS',
#   'Modelo': 'C-100-1',
#   'No_Serie': 'ES00199',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8941'}},
#  {'Area': 'CEYE',
#   'Cliente': 'CENTRO DE ESPECIALIDADES MEDICAS RIO',
#   'Equipo': 'AUTOCLAVE',
#   'Fecha': '03/06/21',
#   'Folio': '2120',
#   'Marca': 'LORMA',
#   'Modelo': 'AV28L',
#   'No_Serie': '20010',
#   'Servicio': 'COORECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb898b'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'GUARPA',
#   'Equipo': 'ELECTROCAUTERIO',
#   'Fecha': '20/05/21',
#   'Folio': '2082',
#   'Marca': 'ASPEN EXCALIBUR',
#   'Modelo': '02FGE087',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8965'}},
#  {'Area': 'CONSULTORIO QUIMIO',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'BAUMANOMETRO',
#   'Fecha': '12/06/21',
#   'Folio': '2127',
#   'Marca': 'WELCH ALLYN',
#   'Modelo': '297',
#   'No_Serie': '91027202214',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8992'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Equipo': 'BASCULA',
#   'Fecha': '24/05/21',
#   'Folio': '2093-CP',
#   'Marca': 'SECA',
#   'Modelo': '700',
#   'No_Serie': '5.70E+12',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8970'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'GUARPA',
#   'Equipo': 'MESA QUIRURGICA',
#   'Fecha': '03/07/21',
#   'Folio': '2158',
#   'Marca': 'MAQUET',
#   'Modelo': '1132.01b3',
#   'No_Serie': '1120',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89b1'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'MSV',
#   'Fecha': '06/07/21',
#   'Folio': '2160',
#   'Marca': 'CONTEC',
#   'Modelo': 'CMS8000',
#   'No_Serie': 'AX170130039',
#   'Servicio': 'PREVENTIVO/CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89b3'}},
#  {'Cliente': 'EMPHI',
#   'Equipo': 'BOMBA DE INFUSION',
#   'Fecha': '22/07/21',
#   'Folio': '2184',
#   'Marca': 'HOSPIRA',
#   'Modelo': 'LIFECARE 5000',
#   'No_Serie': '96376968',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89cb'}},
#  {'Area': 'GAMAGRAFÍA',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'BAUMANOMETRO',
#   'Fecha': '17/07/21',
#   'Folio': '2172',
#   'Marca': 'WELCHALLYN',
#   'Modelo': '297',
#   'No_Serie': '90930215039',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89bf'}},
#  {'Area': 'NA',
#   'Cliente': 'MENDOZA BARBOSA',
#   'Equipo': 'MSV',
#   'Fecha': '22/07/21',
#   'Folio': '2183',
#   'Marca': 'MINDRAY',
#   'Modelo': 'uMEC12',
#   'No_Serie': 'KQ-14065123',
#   'Servicio': 'ENTREGA',
#   '_id': {'$oid': '610750456fcd07beffdb89ca'}},
#  {'Area': 'CONSULTORIO 2',
#   'Cliente': 'MENDOZA BARBOSA',
#   'Equipo': 'LAMPARA DE HENDIDURA',
#   'Fecha': '26/07/21',
#   'Folio': '2204',
#   'Marca': 'SLIT',
#   'Modelo': 'SL7DL',
#   'No_Serie': '361-J201709355',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89dc'}},
#  {'Equipo': 'ASPIRADOR',
#   'Fecha': '12/01/21',
#   'Folio': '1827',
#   'Marca': 'ESCULTOR',
#   'Modelo': 'EACULTOR-G4',
#   'No_Serie': 'MX-1427',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8860'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'GUARPA',
#   'Equipo': 'LAMPARA QUIRURGICA',
#   'Fecha': '22/01/21',
#   'Folio': '1840',
#   'Marca': 'BERCHTOLD',
#   'Modelo': 'CHROMOPHARE C-571',
#   'No_Serie': '0',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb886d'}},
#  {'Area': 'UCI',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'CMT-UCI-03',
#   'Equipo': 'CAMA DE TERAPIA',
#   'Fecha': '26/01/21',
#   'Folio': '1845-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1BZaOHojWF5ZEO7-bXZXib8rdx-6FzQTD/view?usp=sharing',
#   'Marca': 'HILLROM',
#   'Modelo': 'SPO2RT',
#   'No_Serie': 'H079AM4163',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8872'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'DESFIBRILADOR',
#   'Fecha': '05/12/20',
#   'Folio': '1851',
#   'Marca': 'ZOLL',
#   'Modelo': 'MSeries',
#   'No_Serie': 'T02G35926',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8878'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Equipo': 'BOMBA DE INFUSION',
#   'Fecha': '28/01/21',
#   'Folio': '1853-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1hKYfMU1lvkzld1zvppqkbfn-mDppC8lX/view?usp=sharing',
#   'Marca': 'B. BRAUN',
#   'Modelo': 'INFUSOMAT FMS',
#   'No_Serie': '114230',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb887a'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'Fundación Mendoza Barbosa.\xa0',
#   'Equipo': 'MSV',
#   'Fecha': '03/02/21',
#   'Folio': '1867',
#   'Marca': 'DINAMAP',
#   'Modelo': 'PRO 400V2',
#   'No_Serie': 'AAX05080037SA',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8888'}},
#  {'Area': 'SALA GRAL. ENF.',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'BOMBA DE INFUSION',
#   'Fecha': '06/02/21',
#   'Folio': '1876',
#   'Marca': 'ABBOT',
#   'Modelo': 'LIFECARE 5000',
#   'No_Serie': '??',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8891'}},
#  {'Area': 'QUIROFANO 3',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'MQ-QX3-03',
#   'Equipo': 'MESA QUIRURGICA',
#   'Fecha': '11/02/21',
#   'Folio': '1895-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1g_h6A9_tPVCJ84KS3nX8DhwrtBlUnaJA/view?usp=sharing',
#   'Marca': 'AMSCO',
#   'Modelo': '2080',
#   'No_Serie': '405691075',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88a4'}},
#  {'Area': 'CUARTO IODO 4',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'LAMPARA DE CUARTO',
#   'Fecha': '13/02/21',
#   'Folio': '1899',
#   'Marca': 'ARIGMED',
#   'Modelo': 'AURORA',
#   'No_Serie': '20A10230',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88a8'}},
#  {'Area': 'CUARTO IODO',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'CAMA ELECTRICA',
#   'Fecha': '16/02/21',
#   'Folio': '1905',
#   'Marca': 'STRYKER',
#   'Modelo': 'FL28C',
#   'No_Serie': 'R22747',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88ae'}},
#  {'Area': 'FARMACIA',
#   'Cliente': 'F. MENDOZA BARBOSA',
#   'Equipo': 'TERMOMETRO  DIGITAL',
#   'Fecha': '24/02/21',
#   'Folio': '1922',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88bf'}},
#  {'Area': 'NA',
#   'Cliente': 'IRAN MORIN',
#   'Equipo': 'CONCENTRADOR DE \nOXIGENO',
#   'Fecha': '10/03/21',
#   'Folio': '1942',
#   'Marca': 'DEDAKJ',
#   'Modelo': 'DE-1A',
#   'No_Serie': 'ND',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88d9'}},
#  {'Area': 'QUIRIFANO 1',
#   'Cliente': 'SMA HEALTH SERVICES ',
#   'Equipo': 'MESA QUIRURGICA',
#   'Fecha': '26/03/21',
#   'Folio': '1971-SMA',
#   'Marca': 'MAQUETTE',
#   'Modelo': 'ALPHAMAXX',
#   'No_Serie': '113322F5',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88f5'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'CME-HOSP-15',
#   'Equipo': 'CAMA ELECTRICA',
#   'Fecha': '10/04/21',
#   'Folio': '1986-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1kumRw7cbfko2TH_yg8bvrM_toAlLSWYW/view?usp=sharing',
#   'Marca': 'STRYKER',
#   'Modelo': 'SECURE 3000',
#   'No_Serie': '0006 15052',
#   'Servicio': 'CORRECTIVO/PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8905'}},
#  {'Cliente': 'CLINICA DEL PARQUE',
#   'Equipo': 'MSV',
#   'Fecha': '15/04/21',
#   'Folio': '1993-CP',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb890c'}},
#  {'Area': 'N/A',
#   'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'MSV',
#   'Fecha': '16/04/21',
#   'Folio': '1994',
#   'Marca': 'SONOLIFE',
#   'Modelo': 'SMARTWAVE12',
#   'No_Serie': '258000622',
#   'Servicio': 'DICTAMEN',
#   '_id': {'$oid': '610750456fcd07beffdb890d'}},
#  {'Cliente': 'GRUPO CREO',
#   'Equipo': 'BASCULA',
#   'Fecha': '27/04/21',
#   'Folio': '2017',
#   'Marca': 'TORINO',
#   'Modelo': 'PERSONA PLUS',
#   'No_Serie': '23957',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8924'}},
#  {'Area': 'NA',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'MSV',
#   'Fecha': '03/05/21',
#   'Folio': '2024',
#   'Marca': 'PHILIPS',
#   'Modelo': 'M3046A',
#   'No_Serie': 'DE85007702',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb892b'}},
#  {'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'BOMBA DE INFUSION',
#   'Fecha': '05/05/21',
#   'Folio': '2031',
#   'Marca': 'ABOTT',
#   'Modelo': 'LIFECARE 5000',
#   'No_Serie': '96374761',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8932'}},
#  {'Area': 'AMBULATORIA',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'CAMT-AMB-05',
#   'Equipo': 'CAMILLA DE TRASLADO',
#   'Fecha': '07/05/21',
#   'Folio': '2038-CP',
#   'Marca': 'HILL ROM',
#   'Modelo': 'P8000',
#   'No_Serie': 'E342AN5758',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8939'}},
#  {'Area': 'CUNEROS',
#   'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'INCUBADORA',
#   'Fecha': '08/05/21',
#   'Folio': '2042',
#   'Marca': 'INTELEC',
#   'Modelo': 'IEC-2000',
#   'No_Serie': 'IEC-324-M',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb893d'}},
#  {'Area': 'SALA DE LABOR',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'MVS-SL-01',
#   'Equipo': 'MSV',
#   'Fecha': '13/05/21',
#   'Folio': '2054-CP',
#   'Marca': 'SONOLIFE',
#   'Modelo': 'SMARTWAVE12',
#   'No_Serie': '258001132',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8949'}},
#  {'Area': 'QX3',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Equipo': 'MAQUINA DE ANESTESIA',
#   'Fecha': '21/05/21',
#   'Folio': '2089-CP',
#   'Marca': 'DATEX OHMEDA',
#   'Modelo': 'AESTIVA/5',
#   'No_Serie': 'AMRE00954',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb896c'}},
#  {'Area': 'RADIOTERAPIA',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'BASCULA',
#   'Fecha': '22/05/21',
#   'Folio': '2091',
#   'Marca': 'TORINO',
#   'Modelo': 'PERSONA PLUS',
#   'No_Serie': '24388',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb896e'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'QX-FL-01',
#   'Equipo': 'FUENTE DE LUZ',
#   'Fecha': '31/05/21',
#   'Folio': '2105-CP',
#   'Marca': 'KARL STORZ',
#   'Modelo': 'SCB XENON 3000',
#   'No_Serie': 'GA0654986',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb897c'}},
#  {'Area': 'RECUPERACION',
#   'Cliente': 'DR. ARRIAGA ',
#   'Equipo': 'DESFIBRILADOR',
#   'Fecha': '24/06/21',
#   'Folio': '2137',
#   'Marca': 'ZOLL',
#   'Modelo': 'M SERIES',
#   'No_Serie': 'T07B88035',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb899c'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'DR. ARRIGA',
#   'Equipo': 'MESA QUIRURGICA',
#   'Fecha': '24/06/21',
#   'Folio': '2142',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89a1'}},
#  {'Area': 'NA',
#   'Cliente': 'DISTRITO DERMA',
#   'Equipo': 'AUTOCLAVE',
#   'Fecha': '10/07/21',
#   'Folio': '2166',
#   'Marca': 'LORMA',
#   'Modelo': 'AV07',
#   'No_Serie': '010 1104',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89b9'}},
#  {'Cliente': 'GRUPO CREO',
#   'Equipo': 'ECG',
#   'Fecha': '17/07/21',
#   'Folio': '2170',
#   'Marca': 'GE',
#   'Modelo': 'MAC 1200',
#   'No_Serie': '550009946',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89bd'}},
#  {'Area': 'NA',
#   'Cliente': 'BIOS',
#   'Equipo': 'MVS',
#   'Fecha': '11/02/21',
#   'Folio': '1897',
#   'Marca': 'SONOLIFE',
#   'Modelo': 'X7',
#   'No_Serie': 'PMS07A190200037',
#   'Servicio': 'PREVENTIVO/CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88a6'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'MSV',
#   'Fecha': '16/01/21',
#   'Folio': '1832',
#   'Marca': 'COMEN',
#   'Modelo': 'C50',
#   'No_Serie': 'KD150602106',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8865'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'GUARPA',
#   'Equipo': 'MESA QUIRURGICA',
#   'Fecha': '22/01/21',
#   'Folio': '1839',
#   'Marca': 'MAQUET',
#   'Modelo': 'ALPHASTAR 1132.01B3',
#   'No_Serie': '1120',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb886c'}},
#  {'Area': 'NA',
#   'Cliente': 'Bárbara Melo',
#   'Equipo': 'BOMBA DE INFUSION',
#   'Fecha': '23/02/21',
#   'Folio': '1917',
#   'Marca': 'HOSPIRA',
#   'Modelo': 'LIFECARE 5000',
#   'No_Serie': '96377303/96374761',
#   'Servicio': 'PREVENTIVO/CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88ba'}},
#  {'Area': 'UCIN',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'CUTE-UCIN-02',
#   'Equipo': 'CUNA TERMICA',
#   'Fecha': '19/04/21',
#   'Folio': '1997-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/15XTKpsJt5gjFsxvyh7QJlHIaftBuH6Ut/view?usp=sharing',
#   'Marca': 'AIR-SHIELDS VICKERS',
#   'Modelo': 'PM78-1',
#   'No_Serie': 'GX14679',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8910'}},
#  {'Area': 'N/A',
#   'Cliente': 'TERESA CARVAJAL',
#   'Equipo': 'CONCENTRADOR DE O2',
#   'Fecha': '21/04/21',
#   'Folio': '2001',
#   'Marca': 'DEVILBISS',
#   'Modelo': '5 LITER SERIES OXYGEN CONCENTRATOR',
#   'No_Serie': 'B208130783DS',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8914'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'CME-HOSP-05',
#   'Equipo': 'CAMA ELECTRICA',
#   'Fecha': '21/04/21',
#   'Folio': '2002-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1ZAtyi_pr9BpEQhnsrDFt4CoCr0VIfMZn/view?usp=sharing',
#   'Marca': 'STRYKER',
#   'Modelo': 'SECURE 3000',
#   'No_Serie': '0006-1554-1',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8915'}},
#  {'Area': 'UCIN',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'CUTE-UCIN-01',
#   'Equipo': 'CUNA TERMICA',
#   'Fecha': '22/04/21',
#   'Folio': '2008-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/14njYYQRGuo_T11Mp67mMDceyNLiECv8n/view?usp=sharing',
#   'Marca': 'AIR SHIELDS',
#   'Modelo': 'PM78-1',
#   'No_Serie': 'QY22961',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb891b'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'MSV',
#   'Fecha': '08/05/21',
#   'Folio': '2041',
#   'Marca': 'CONTEC',
#   'Modelo': 'CMS9000',
#   'No_Serie': 'AT1504100060',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb893c'}},
#  {'Area': 'AMBULATORIA',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'CAMT-AMB-03',
#   'Equipo': 'CAMILLA DE TRASLADO',
#   'Fecha': '12/05/21',
#   'Folio': '2048-CP',
#   'Marca': 'HILLROOM',
#   'Modelo': 'P8000',
#   'No_Serie': 'F259AM1280',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8943'}},
#  {'Area': 'CONSULTORIO',
#   'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'BASCULA',
#   'Fecha': '14/05/21',
#   'Folio': '2058',
#   'Marca': 'N7A',
#   'Modelo': 'N/A',
#   'No_Serie': 'N/A',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb894d'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'QX-KRT-01',
#   'Equipo': 'MEDICAL CART',
#   'Fecha': '31/05/21',
#   'Folio': '2106-CP',
#   'Marca': 'KARL STORZ',
#   'Modelo': '9601M',
#   'No_Serie': '13010055',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb897d'}},
#  {'Area': 'RESGUARDO BIOMEDICA',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'UC-RB-02',
#   'Equipo': 'UNIDAD DE CONTROL',
#   'Fecha': '01/06/21',
#   'Folio': '2115-CP',
#   'Marca': 'STRYKER',
#   'Modelo': 'TPS CONSOLE',
#   'No_Serie': '12963',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8986'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'DR. ARRIGA',
#   'Equipo': 'MAQUINA DE ANESTESIA',
#   'Fecha': '24/06/21',
#   'Folio': '2144',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89a3'}},
#  {'Area': 'QUIROFANO 3',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'MSV-AMB-05',
#   'Equipo': 'MSV',
#   'Fecha': '25/06/21',
#   'Folio': '2149-CP',
#   'Marca': 'RISINGMED',
#   'Modelo': 'RPM90002B',
#   'No_Serie': '05BK000013',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89a8'}},
#  {'Area': 'UCIN',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'CUTE-UCIN-02',
#   'Equipo': 'CUNA TERMICA',
#   'Fecha': '08/07/21',
#   'Folio': '2165-CP',
#   'Marca': 'AIR SHIELDS',
#   'Modelo': 'SYSTEM 7810',
#   'No_Serie': 'GX02900',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89b8'}},
#  {'Area': 'ENFERMERÍA ',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'BAUMANOMETRO PEDIATRICO',
#   'Fecha': '17/07/21',
#   'Folio': '2171',
#   'Marca': 'MEDSTAR',
#   'Modelo': '123',
#   'No_Serie': '51444',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89be'}},
#  {'Area': 'RECUPERACION',
#   'Cliente': 'GUARPA',
#   'Equipo': 'MSV',
#   'Fecha': '21/07/21',
#   'Folio': '2182',
#   'Marca': 'WELCHALLYN',
#   'Modelo': 'ENCORE',
#   'No_Serie': '2042013',
#   'Servicio': 'PREVENTIVO/CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89c9'}},
#  {'Area': 'CONSULTORIO 3',
#   'Cliente': 'MENDOZA BARBOSA',
#   'Equipo': 'LAMPARA DE HENDIDURA',
#   'Fecha': '26/07/21',
#   'Folio': '2203',
#   'Marca': 'STALLION MEDICAL INC',
#   'Modelo': 'STALLION S350C SLIT LAMP',
#   'No_Serie': '1.81E+12',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89db'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'GUARPA',
#   'Equipo': 'MESA QUIRURGICA',
#   'Fecha': '22/01/21',
#   'Folio': '1838',
#   'Marca': 'AMSCO',
#   'Modelo': '2080',
#   'No_Serie': '426796001',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb886b'}},
#  {'Area': 'PET-CT',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'CALENTADOR',
#   'Fecha': '30/01/21',
#   'Folio': '1861',
#   'Marca': 'KALORTIX',
#   'Modelo': 'TERMOVIST',
#   'No_Serie': '15066',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8882'}},
#  {'Area': 'RECUPERACION',
#   'Cliente': 'GUARPA',
#   'Equipo': 'COMPRESOR VASCULAR',
#   'Fecha': '29/01/21',
#   'Folio': '1857',
#   'Marca': 'COVIDIEN',
#   'Modelo': 'KENDALL SCD 700 SERIES',
#   'No_Serie': 'V1415646SX',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb887e'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'CME-HOSP-09',
#   'Equipo': 'CAMA ELECTRICA',
#   'Fecha': '06/02/21',
#   'Folio': '1881-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1YgyBGacnTcC-z1Plg6WSC45lsg6dkFuo/view?usp=sharing',
#   'Marca': 'STRYKER',
#   'Modelo': 'SECURE 3000',
#   'No_Serie': '0005-15395',
#   'Notas': 'cople aluminio',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8896'}},
#  {'Area': 'CONSULTORIOS',
#   'Cliente': 'VISION LASER',
#   'Equipo': 'UNIDAD DE OFTALMOLOGIA',
#   'Fecha': '02/02/21',
#   'Folio': '1864',
#   'Marca': 'S4OPTIK',
#   'Modelo': '2500 CB',
#   'No_Serie': '204-2500-37',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8885'}},
#  {'Area': 'NA',
#   'Cliente': 'Jessica Lopez',
#   'Equipo': 'CONCENTRADOR DE OXIGENO',
#   'Fecha': '16/02/21',
#   'Folio': '1902',
#   'Marca': 'PHILIPS',
#   'Modelo': 'EVERFLO',
#   'No_Serie': '1239159',
#   'Servicio': 'DIAGNOSTICO',
#   '_id': {'$oid': '610750456fcd07beffdb88ab'}},
#  {'Area': 'SALA GRAL. ENF.',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'ELECTROCARDIAGRAMA',
#   'Fecha': '06/02/21',
#   'Folio': '1879',
#   'Marca': 'WLLCH ALLYN',
#   'Modelo': 'SCHILLER AT-1',
#   'No_Serie': '192. 02529',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8894'}},
#  {'Area': 'UCI',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'MSV-UCI-03',
#   'Equipo': 'MSV',
#   'Fecha': '24/02/21',
#   'Folio': '1919-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1eIFXopk1oRadicqV4I5m8WAL2onShjPj/view?usp=sharing',
#   'Marca': 'MINDRAY',
#   'Modelo': 'MEC2000',
#   'No_Serie': 'CV-49113430',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88bc'}},
#  {'Area': 'QUIROFANO 1',
#   'Cliente': 'GUARPA',
#   'Equipo': 'CALENTADOR DE SABANAS',
#   'Fecha': '09/02/21',
#   'Folio': '1886',
#   'Marca': 'NELLCOR',
#   'Modelo': 'WARMTOUCH',
#   'No_Serie': 'CI0610J036',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb889b'}},
#  {'Area': 'FARMACIA',
#   'Cliente': 'F. MENDOZA BARBOSA',
#   'Equipo': 'TERMOMETRO HIGROMETRO',
#   'Fecha': '24/02/21',
#   'Folio': '1921',
#   'Marca': 'HTC-1',
#   'Modelo': 'HTC-1',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88be'}},
#  {'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'BAUMANOMETRO',
#   'Fecha': '10/02/21',
#   'Folio': '1892',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88a1'}},
#  {'Area': 'FARMACIA',
#   'Cliente': 'F. MENDOZA BARBOSA',
#   'Equipo': 'TERMOMETRO ANÁLOGICO ',
#   'Fecha': '24/02/21',
#   'Folio': '1923',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88c0'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'CME-HOSP-18',
#   'Equipo': 'CAMA ELECTRICA',
#   'Fecha': '26/03/21',
#   'Folio': '1963-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1mLUOLO4ELg7S27e6zgxMwzglYaIf0_LA/view?usp=sharing',
#   'Marca': 'HILL ROM',
#   'Modelo': 'ADVANTA',
#   'No_Serie': 'E239AB7006',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88ee'}},
#  {'Area': 'QUIROFANO 1',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'MSV-QX1-01',
#   'Equipo': 'MSV',
#   'Fecha': '15/02/21',
#   'Folio': '1901-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1qrOWELAI9PHmX3CtDq44F1UsTaxtU9lP/view?usp=sharing',
#   'Marca': 'CONTEC',
#   'Modelo': 'CMS8000',
#   'No_Serie': '17080700037',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88aa'}},
#  {'Area': 'DIALISIS Y TRANSPLANTE',
#   'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'BASCULA MECANICA',
#   'Fecha': '05/04/21',
#   'Folio': '1981',
#   'Marca': 'NUEVO LEON',
#   'Modelo': 'CLINICA 160',
#   'No_Serie': '113211',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8900'}},
#  {'Area': 'NA',
#   'Cliente': 'Bárbara Melo',
#   'Equipo': 'BOMBA DE INFUSION',
#   'Fecha': '19/02/21',
#   'Folio': '1911',
#   'Marca': 'ABBOTT',
#   'Modelo': 'LIFECARE 5000',
#   'No_Serie': '96377303',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88b4'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'CME-HOSP-03',
#   'Equipo': 'CAMA ELECTRICA',
#   'Fecha': '26/02/21',
#   'Folio': '1925-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1VpFKwRv0EEWyIlSNG9bZVjAhf4E2bSF-/view?usp=sharing',
#   'Marca': 'HILL ROM',
#   'Modelo': 'ADVANCE 1000',
#   'No_Serie': '1105-58D76',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88c5'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'MSV',
#   'Fecha': '07/04/21',
#   'Folio': '1984',
#   'Marca': 'CONTEC',
#   'Modelo': 'CMS6000',
#   'No_Serie': 'AVCJ100050',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8903'}},
#  {'Area': 'SIMULACION',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'ASPIRADOR',
#   'Fecha': '06/03/21',
#   'Folio': '1936',
#   'Marca': 'SHUCO INC',
#   'Modelo': '5711 130',
#   'No_Serie': '791520',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88d3'}},
#  {'Cliente': 'CLINICA DEL PARQUE',
#   'Equipo': 'CUNA TERMICA',
#   'Fecha': '15/04/21',
#   'Folio': '1992-CP',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb890b'}},
#  {'Cliente': 'RINO-Q',
#   'Equipo': 'COMPRESERO',
#   'Fecha': '06/03/21',
#   'Folio': '1938',
#   'Marca': 'BTL',
#   'Modelo': 'ND',
#   'No_Serie': 'ND',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88d5'}},
#  {'Area': 'QX',
#   'Cliente': 'SMA HEALTH SERVICES ',
#   'Equipo': 'LIGASURE',
#   'Fecha': '21/04/21',
#   'Folio': '2000',
#   'Marca': 'VALLEYLAB',
#   'Modelo': 'LIGASURE',
#   'No_Serie': 'L0L1941V',
#   'Servicio': 'CORERCTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8913'}},
#  {'Area': 'QUIRIFANO 2',
#   'Cliente': 'SMA HEALTH SERVICES ',
#   'Equipo': 'MSV',
#   'Fecha': '26/03/21',
#   'Folio': '1965-SMA',
#   'Marca': 'WELCH ALLYN',
#   'Modelo': 'PROPAQ CS',
#   'No_Serie': 'GA-116753',
# ...
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'MSV-URG-02',
#   'Equipo': 'MSV',
#   'Fecha': '25/06/21',
#   'Folio': '2147-CP',
#   'Marca': 'SONOLIFE',
#   'Modelo': 'SMARTWAVE 12',
#   'No_Serie': '31508075',
#   'Servicio': 'CORRECTIVO/PREV',
#   '_id': {'$oid': '610750456fcd07beffdb89a6'}},
#  {'Area': 'QUIROFANO 2',
#   'Cliente': 'GUARPA',
#   'Equipo': 'INFUSOR',
#   'Fecha': '07/07/21',
#   'Folio': '2163',
#   'Marca': 'ECON II',
#   'Modelo': 'VARI-FLOW',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89b6'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'FUNDACION MENDOZA BARBOSA',
#   'Equipo': 'MAQUINA DE ANESTESIA',
#   'Fecha': '19/07/21',
#   'Folio': '2178',
#   'Marca': 'DRAGGER',
#   'Modelo': 'NARKOMED MOBILE',
#   'No_Serie': '10332',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89c5'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'MENDOZA BARBOSA',
#   'Equipo': 'MICROQUERATOMO',
#   'Fecha': '26/07/21',
#   'Folio': '2198',
#   'Marca': 'BAUSCH & LOMB',
#   'Modelo': 'HANSATOME HT 115',
#   'No_Serie': '3976',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89d6'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'MENDOZA BARBOSA',
#   'Equipo': 'LAMPARA QUIRUGICA',
#   'Fecha': '26/07/21',
#   'Folio': '2200',
#   'Marca': 'DRE',
#   'Modelo': 'DRE021312',
#   'No_Serie': '1209010',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89d8'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'MENDOZA BARBOSA',
#   'Equipo': 'LAMPARA UV',
#   'Fecha': '26/07/21',
#   'Folio': '2201',
#   'Marca': 'CSO',
#   'Modelo': 'ILLUMINATORE DI LUCE UV-A',
#   'No_Serie': '9031419',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89d9'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'BI-HO-10',
#   'Equipo': 'BOMBA DE INFUSION',
#   'Fecha': '25/01/21',
#   'Folio': '1846-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1EphyYadl6UgxGX1k2tPYFvNPhAh75tBw/view?usp=sharing',
#   'Marca': 'HOSPIRA',
#   'Modelo': 'HOSPIRA 5000',
#   'No_Serie': '96377359',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8873'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'GUARPA',
#   'Equipo': 'LAMPARA QUIRURGICA',
#   'Fecha': '29/01/21',
#   'Folio': '1856',
#   'Marca': 'SKYTRON',
#   'Modelo': 'MILLENIUM GOLD',
#   'No_Serie': '6990012',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb887d'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'Fundación Mendoza Barbosa.\xa0',
#   'Equipo': 'MSV',
#   'Fecha': '03/02/21',
#   'Folio': '1868',
#   'Marca': 'GE',
#   'Modelo': 'DASH 3000',
#   'No_Serie': 'SBG07108853GA',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8889'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'Fundación Mendoza Barbosa.\xa0',
#   'Equipo': 'DESFIBRILADOR',
#   'Fecha': '03/02/21',
#   'Folio': '1870',
#   'Marca': 'PHILIPS',
#   'Modelo': 'M4735A',
#   'No_Serie': 'US00113249',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb888b'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'Fundación Mendoza Barbosa.\xa0',
#   'Equipo': 'AUTOCLAVE',
#   'Fecha': '04/02/21',
#   'Folio': '1873',
#   'Marca': 'STATIM',
#   'Modelo': '1102',
#   'No_Serie': '207971 A',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb888e'}},
#  {'Area': 'SALA GRAL. ENF.',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'BOMBA DE INFUSION',
#   'Fecha': '06/02/21',
#   'Folio': '1877',
#   'Marca': 'ABBOT',
#   'Modelo': 'LIFECARE 5000',
#   'No_Serie': '??',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8892'}},
#  {'Area': 'TOCOCIRUGIA',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'DES-TOC-01',
#   'Equipo': 'DESFIBRILADOR',
#   'Fecha': '04/03/21',
#   'Folio': '1932-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1q--7M9_4J2rX7QCXSV830p5QFqI1KWba/view?usp=sharing',
#   'Marca': 'MEDTRONIC',
#   'Modelo': 'LIFEPAK 20',
#   'No_Serie': '30891996',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88cf'}},
#  {'Cliente': 'SERGIO SOLANO',
#   'Equipo': 'CAMILLA',
#   'Fecha': '05/03/21',
#   'Folio': '1933',
#   'Marca': 'MIDMARK',
#   'Modelo': 'K550-001',
#   'No_Serie': 'TEG001497',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88d0'}},
#  {'Area': 'SALA DE LABOR',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'MQ-SLAB-01',
#   'Equipo': 'MESA QUIRURGICA',
#   'Fecha': '18/03/21',
#   'Folio': '1953-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1jTsYmqE1PfhpkhoqMzZIccUAa5ZBWAzy/view?usp=sharing',
#   'Marca': 'SHAMPAINE',
#   'Modelo': 'SIN MODELO',
#   'No_Serie': 'SIN NO SERIE',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88e4'}},
#  {'Area': 'CEYE',
#   'Cliente': 'GUARPA',
#   'Equipo': 'COMPRESOR VASCULAR',
#   'Fecha': '20/03/21',
#   'Folio': '1954',
#   'Marca': 'KENDALL',
#   'Modelo': 'SCD EXPRESS',
#   'No_Serie': 'V0826992',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88e5'}},
#  {'Cliente': 'OLIMED',
#   'Equipo': 'MSV',
#   'Fecha': '22/03/21',
#   'Folio': '1956',
#   'Marca': 'GOLDWAY',
#   'Modelo': 'G 30',
#   'No_Serie': 'CN42717762',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88e7'}},
#  {'Area': 'QUIROFANO 1',
#   'Cliente': 'SMA HEALTH SERVICES ',
#   'Equipo': 'MSV',
#   'Fecha': '26/03/21',
#   'Folio': '1967-SMA',
#   'Marca': 'CRITICARE',
#   'Modelo': 'NCOMPASS',
#   'No_Serie': '114727527',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88f2'}},
#  {'Area': 'QUIROFANO 2 ',
#   'Cliente': 'SMA HEALTH SERVICES ',
#   'Equipo': 'MESA QUIRURGICA ',
#   'Fecha': '26/03/21',
#   'Folio': '1973-SMA',
#   'Marca': 'AMSCO',
#   'Modelo': '2080L',
#   'No_Serie': 'R402302013',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88f8'}},
#  {'Cliente': 'ARTRO HOPE',
#   'Equipo': 'CAMARA',
#   'Fecha': '21/04/21',
#   'Folio': '2006',
#   'Marca': 'STRYKER',
#   'Modelo': 'I588 AIM',
#   'No_Serie': '16E032124',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8919'}},
#  {'Area': 'QUIROFANO 2',
#   'Cliente': 'GUARPA',
#   'Equipo': 'MAQUINA DE ANESTESIA',
#   'Fecha': '30/04/21',
#   'Folio': '2023',
#   'Marca': 'DRAGER',
#   'Modelo': 'NARKOMED GS',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb892a'}},
#  {'Area': 'N/A',
#   'Cliente': 'DR. ARRIAGA',
#   'Equipo': 'LAMPARA QUIRURGICA DE EMERGENCIA',
#   'Fecha': '05/05/21',
#   'Folio': '2032',
#   'Marca': 'ECOMED',
#   'Modelo': 'G3',
#   'No_Serie': 'G3MLZY21L27002',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8933'}},
#  {'Area': 'N/A',
#   'Cliente': 'AXIOMA',
#   'Equipo': 'MSV',
#   'Fecha': '06/05/21',
#   'Folio': '2034',
#   'Marca': 'PHILIPS',
#   'Modelo': 'M3046A',
#   'No_Serie': 'DE85009202',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8935'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'ELECTROCAUTERIO',
#   'Fecha': '08/05/21',
#   'Folio': '2043',
#   'Marca': 'CONMED',
#   'Modelo': '5600-002',
#   'No_Serie': '96CGS007',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb893e'}},
#  {'Area': 'UCIN',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'FOT-UCIN-01',
#   'Equipo': 'FOTOTERAPIA',
#   'Fecha': '18/05/21',
#   'Folio': '2070-CP',
#   'Marca': 'OHMEDA',
#   'Modelo': 'BILLYBLANKET',
#   'No_Serie': 'HCFB50241',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8959'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'QX-ISF-01',
#   'Equipo': 'INSUFLADOR',
#   'Fecha': '31/05/21',
#   'Folio': '2104-CP',
#   'Marca': 'KARL STORZ',
#   'Modelo': 'THERMOFLATOR SCB',
#   'No_Serie': '09777-B',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb897b'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'DR. ARRIAGA',
#   'Equipo': 'ELECTROCAUTERIO',
#   'Fecha': '24/06/21',
#   'Folio': '2140',
#   'Marca': 'SONOLIFE',
#   'Modelo': 'ESU-300',
#   'No_Serie': 'PE19097931',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb899f'}},
#  {'Area': 'QUIROFANO 2',
#   'Cliente': 'GUARPA',
#   'Equipo': 'ASÍRADOR',
#   'Fecha': '07/07/21',
#   'Folio': '2162',
#   'Marca': 'EASY VAC',
#   'Modelo': 'PM-60',
#   'No_Serie': '75439',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89b5'}},
#  {'Area': 'QUIROFANO 1',
#   'Cliente': 'GUARPA',
#   'Equipo': 'LAMPARA QUIRUGICA',
#   'Fecha': '21/07/21',
#   'Folio': '2179',
#   'Marca': 'BERCHTOLD',
#   'Modelo': 'CHROMOPHARE C-571',
#   'No_Serie': '571075-01980008',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89c6'}},
#  {'Cliente': 'EMPHI',
#   'Equipo': 'BOMBA DE INFUSION',
#   'Fecha': '22/07/21',
#   'Folio': '2185',
#   'Marca': 'HOSPIRA',
#   'Modelo': 'LIFECARE 5000',
#   'No_Serie': '96378139',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89cc'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'DR LUIS RODRIGUEZ',
#   'Equipo': 'LAMPARA QUIRUGICA',
#   'Fecha': '24/07/21',
#   'Folio': '2196',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89d4'}},
#  {'Area': 'QUIROFANO 3',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'MQA-QX3-03',
#   'Equipo': 'MAQUINA DE ANESTESIA',
#   'Fecha': '02/02/21',
#   'Folio': '1866-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/17xpD1hCbwqFXJ7i3GPhpkNJgL1-73qut/view?usp=sharing',
#   'Marca': 'DATEX OHMEDA',
#   'Modelo': 'AESPIRE',
#   'No_Serie': 'AMXL01492',
#   'Servicio': 'PREVENTIVO/CAL',
#   '_id': {'$oid': '610750456fcd07beffdb8887'}},
#  {'Area': 'QUIROFANO 2',
#   'Cliente': 'GUARPA',
#   'Equipo': 'CALENTADOR DE SABANAS',
#   'Fecha': '09/02/21',
#   'Folio': '1889',
#   'Marca': '3M',
#   'Modelo': '775',
#   'No_Serie': '100655',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb889e'}},
#  {'Area': 'NA',
#   'Cliente': 'Elvira',
#   'Equipo': 'BOMBA DE INFUSION',
#   'Fecha': '12/02/21',
#   'Folio': '1898',
#   'Marca': 'ABBOT',
#   'Modelo': 'LIFECARE 5000',
#   'No_Serie': '96375762',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88a7'}},
#  {'Area': 'UCI',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'DES.UCI-01',
#   'Equipo': 'DESFIBRILADOR',
#   'Fecha': '17/02/21',
#   'Folio': '1906-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1bgIH5L1tFNIRouxbkOqLhirtWjCX7Gri/view?usp=sharing',
#   'Marca': 'ZOLL',
#   'Modelo': 'M SERIES CCT',
#   'No_Serie': 'T08A98503',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88af'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'CME- HOSP-30',
#   'Equipo': 'CAMA ELECTRICA',
#   'Fecha': '02/02/21',
#   'Folio': '1928-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1qKqxs_yY8b_jZM8bcb8du3s30V-ywJYl/view?usp=sharing',
#   'Marca': 'HILL ROM',
#   'Modelo': '1000 SERIES',
#   'No_Serie': '1104-30A57-A',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88cb'}},
#  {'Area': 'NA',
#   'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'DESFIBRILADOR ',
#   'Fecha': '10/03/21',
#   'Folio': '1943',
#   'Marca': 'PHYSIO CONTROL',
#   'Modelo': 'LIFEPAK 9',
#   'No_Serie': '402327',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88da'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'MSV-HO-01',
#   'Equipo': 'MSV',
#   'Fecha': '24/03/21',
#   'Folio': '1959-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1hGAbVmak_mrTNx5BjgGMpK7WmQpNJDwM/view?usp=sharing',
#   'Marca': 'MINDRAY',
#   'Modelo': 'UMEC12',
#   'No_Serie': 'KQ-97025285',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88ea'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'GUARPA',
#   'Equipo': 'ELECTROCAUTERIO ',
#   'Fecha': '24/03/21',
#   'Folio': '1961',
#   'Marca': 'CONMED',
#   'Modelo': 'EXCALIBUR PLUS PC',
#   'No_Serie': '02F GE 087',
#   'Servicio': 'CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88ec'}},
#  {'Area': 'RECUPERACION',
#   'Cliente': 'SMA HEALTH SERVICES ',
#   'Equipo': 'DESFIBRILADOR',
#   'Fecha': '26/03/21',
#   'Folio': '1974-SMA',
#   'Marca': 'PHISIO CONTROL',
#   'Modelo': 'LIFEPAK 20',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88f9'}},
#  {'Area': 'URGENCIAS',
#   'Cliente': 'CLINICA SANTA CRUZ',
#   'Equipo': 'BASCULA',
#   'Fecha': '29/03/21',
#   'Folio': '1977',
#   'Marca': 'BAME',
#   'Modelo': '420',
#   'No_Serie': '94-1983',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb88fc'}},
#  {'Area': 'UCI',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'VENT-UCI-02',
#   'Equipo': 'VENTILADOR DE TERAPIA',
#   'Fecha': '22/04/21',
#   'Folio': '2007-CP',
#   'Link_Drive': 'https://drive.google.com/file/d/1EQ4-ZhVWg_k0cupDf_WG_gU9cml8_74T/view?usp=sharing',
#   'Marca': 'VIASYS',
#   'Modelo': 'VELA',
#   'No_Serie': 'AFT03365',
#   'Servicio': 'CORRECTIVO/INSTALACION',
#   '_id': {'$oid': '610750456fcd07beffdb891a'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'ESPECIALIDADES MEDICAS DE RIO VERDE',
#   'Equipo': 'MAQUINA DE ANESTESIA',
#   'Fecha': '23/04/21',
#   'Folio': '2010',
#   'Marca': 'DRAGER',
#   'Modelo': 'NARKOMED',
#   'No_Serie': '16229',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb891d'}},
#  {'Area': 'RECUPERACION ',
#   'Cliente': 'ESPECIALIDADES MEDICAS DE RIO VERDE',
#   'Equipo': 'MSV',
#   'Fecha': '23/04/21',
#   'Folio': '2011',
#   'Marca': 'MINDRAY',
#   'Modelo': 'MEC-509B',
#   'No_Serie': 'X2C-5797',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb891e'}},
#  {'Area': 'UCIN',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'INC-UCIN-01',
#   'Equipo': 'INCUBADORA',
#   'Fecha': '17/05/21',
#   'Folio': '2065-CP',
#   'Marca': 'AIR SHIELDS',
#   'Modelo': 'C100',
#   'No_Serie': 'UG22066',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8954'}},
#  {'Area': 'RESGUARDO BIOMEDICA',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'FOT-REB-01',
#   'Equipo': 'FOTOTERAPIA',
#   'Fecha': '18/05/21',
#   'Folio': '2072-CP',
#   'Marca': 'AIR SHIELDS',
#   'Modelo': 'PT533-1',
#   'No_Serie': 'YH03908',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb895b'}},
#  {'Area': 'TOCOCIRUGIA',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'TC-TC-03',
#   'Equipo': 'TOCOCARDIOGRAFO',
#   'Fecha': '19/05/21',
#   'Folio': '2074-CP',
#   'Marca': 'HUNTLEHEIGHCARE',
#   'Modelo': 'SONICAID',
#   'No_Serie': '738XA0130330-06',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb895d'}},
#  {'Area': 'HOSPITALIZACION',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'PENDIENTE',
#   'Equipo': 'CAMA ELECTRICA',
#   'Fecha': '25/05/21',
#   'Folio': '2099-CP',
#   'Link_Drive': 'SE CORRIGE EL FOLIO 2096',
#   'Marca': 'STRYKER',
#   'Modelo': 'S3',
#   'No_Serie': '110115730',
#   'Servicio': 'PREVENTIVO/CORRECTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8976'}},
#  {'Area': 'CONSULTORIO QUIMIO',
#   'Cliente': 'GRUPO CREO',
#   'Equipo': 'BAUMANOMETRO',
#   'Fecha': '12/06/21',
#   'Folio': '2128',
#   'Marca': 'WELCH ALLYN',
#   'Modelo': '297',
#   'No_Serie': '91027213938',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb8993'}},
#  {'Area': 'QUIROFANO 3',
#   'Cliente': 'CLINICA DEL PARQUE',
#   'Codigo': 'MQ-QX3-03',
#   'Equipo': 'MESA QUIRURGICA',
#   'Fecha': '28/06/21',
#   'Folio': '2151-CP',
#   'Marca': 'AMSCO',
#   'Modelo': '2080',
#   'No_Serie': '405691075',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89aa'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'GUARPA',
#   'Equipo': 'MESA QUIRURGICA',
#   'Fecha': '03/07/21',
#   'Folio': '2159',
#   'Marca': 'AMSCO',
#   'Modelo': '2080',
#   'No_Serie': '426796001',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89b2'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'DR LUIS RODRIGUEZ',
#   'Equipo': 'MAQUINA DE ANESTESIA',
#   'Fecha': '24/07/21',
#   'Folio': '2191',
#   'Marca': 'DRAGER',
#   'Modelo': 'NARKOMED 2C',
#   'No_Serie': '10116',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89cf'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'DR LUIS RODRIGUEZ',
#   'Equipo': 'MSV',
#   'Fecha': '24/07/21',
#   'Folio': '2192',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89d0'}},
#  {'Area': 'QUIROFANO',
#   'Cliente': 'DR LUIS RODRIGUEZ',
#   'Equipo': 'ELECTROCAUTERIO',
#   'Fecha': '24/07/21',
#   'Folio': '2195',
#   'Marca': 'CONMED',
#   'Modelo': 'EXCALIBUR PLUS',
#   'No_Serie': '03BGE020',
#   'Servicio': 'PREVENTIVO',
#   '_id': {'$oid': '610750456fcd07beffdb89d3'}}]

# %% [markdown]
# ### Writing JSON
#
# "Convert the object to a JSON string. Note ```NaN```’s and ```None``` will be converted to null and datetime objects will be converted to UNIX timestamps."
#
# ```DataFrame.to_json(path_or_buf=None, orient=None, date_format=None, double_precision=10, force_ascii=True, date_unit='ms', default_handler=None, lines=False, compression='infer', index=True)```
#
# "**Parameters:**
# * **path_or_buf:** *string or file handle, optional*. File path or object. If not specified, the result is returned as a string.
# * **orient:** *string*. Indication of expected JSON string format.
#   * Series
#     * default is ‘index’
#     * allowed values are: {‘split’,’records’,’index’,’table’}
#   * DataFrame
#     * default is ‘columns’
#     * allowed values are: {‘split’,’records’,’index’,’columns’,’values’,’table’}
#   * The format of the JSON string
#     * ‘split’ : dict like {‘index’ -> [index], ‘columns’ -> [columns], ‘data’ -> [values]}
#     * ‘records’ : list like [{column -> value}, … , {column -> value}]
#     * ‘index’ : dict like {index -> {column -> value}}
#     * ‘columns’ : dict like {column -> {index -> value}}
#     * ‘values’ : just the values array
#     * ‘table’ : dict like {‘schema’: {schema}, ‘data’: {data}} describing the data, and the data component is like orient='records'.
# * ..."
#
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_json.html

# %%
# write DataFrame to disk with records indication
df.to_json('turtles.json', orient='records')

# %% [markdown]
# ### Reading JSON
#
# "Convert a JSON string to pandas object."
#
# ```pandas.read_json(path_or_buf=None, orient=None, typ='frame', dtype=True, convert_axes=True, convert_dates=True, keep_default_dates=True, numpy=False, precise_float=False, date_unit=None, encoding=None, lines=False, chunksize=None, compression='infer')```
#
# "**Parameters:**
# * **path_or_buf:** *a valid JSON string or file-like, default: ```None```*. The string could be a URL. Valid URL schemes include http, ftp, s3, gcs, and file. For file URLs, a host is expected. For instance, a local file could be file://localhost/path/to/table.json
# * **orient:** *string*. Indication of expected JSON string format. Compatible JSON strings can be produced by ```to_json()``` with a corresponding orient value. The set of possible orients is:
#   * 'split' : dict like {index -> [index], columns -> [columns], data -> [values]}
#   * 'records' : list like [{column -> value}, ... , {column -> value}]
#   * 'index' : dict like {index -> {column -> value}}
#   * 'columns' : dict like {column -> {index -> value}}
#   * 'values' : just the values array
#
#   The allowed and default values depend on the value of the typ parameter.
#   * when typ == 'series',
#     * allowed orients are {'split','records','index'}
#     * default is 'index'
#     * The Series index must be unique for orient 'index'.
#   * when typ == 'frame',
#     * allowed orients are {'split','records','index', 'columns','values', 'table'}
#     * default is 'columns'
#     * The DataFrame index must be unique for orients 'index' and 'columns'.
#     * The DataFrame columns must be unique for orients 'index', 'columns', and 'records'.
# * ...
#
# **Returns: result:** *Series or DataFrame*, depending on the value of typ."
#
# http://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_json.html

# %%
# read json from disk
pd.read_json('turtles.json')
# Out:
#         name    mask    weapon
# 0    Raphael     red       sai
# 1  Donatello  purple  bo staff

# %% [markdown]
# # Pickling
# * "The `pickle` module implements binary protocols for serializing and de-serializing a Python object structure."
# * "*Pickling* is the process whereby a Python object hierarchy is converted into a byte stream, and *unpickling* is the inverse operation, whereby a byte stream (from a binary file or bytes-like object) is converted back into an object hierarchy."
# * "*Pickling* (and *unpickling*) is alternatively known as “serialization”, “marshalling,” or “flattening”."
#
# https://docs.python.org/3.3/library/pickle.html#module-pickle
#
# ## Pickle vs JSON
#
# | -                     | Pickle | JSON               |
# |:----------------------|:-------|:-------------------|
# | Serialization         | Binary | Text               |
# | Human-readable        | No     | Yes                |
# | Python-specific       | Yes    | No (interoperable) |
# | Python build-in types | Yes    | No (default)       |
# | Custom classes        | Yes    | No                 |
#
# https://docs.python.org/3.3/library/pickle.html#comparison-with-json
#
#
# ## What can be pickled and unpickled?
# * "`None`, `True`, and `False`
# * integers, floating point numbers, complex numbers
# * strings, bytes, bytearrays
# * tuples, lists, sets, and dictionaries containing only picklable objects
# * functions defined at the top level of a module
# * built-in functions defined at the top level of a module
# * classes that are defined at the top level of a module
# * instances of such classes whose `__dict__` or the result of calling `__getstate__()` is picklable (see section [Pickling Class Instances](https://docs.python.org/3.3/library/pickle.html#pickle-inst) for details)."
#
# `PicklingError` will be raised when trying to pickle unpickle objects.
#
# https://docs.python.org/3.3/library/pickle.html#what-can-be-pickled-and-unpickled

# %%
x
# Out:
# [1, 'simple', 'list']

# %%
import pickle
pickle.dumps(x)
# Out:
# b'\x80\x03]q\x00(K\x01X\x06\x00\x00\x00simpleq\x01X\x04\x00\x00\x00listq\x02e.'

# %%
picklefile = 'picklefile.pickle'
# open file in write and binary mode: 'wb'
with open(picklefile, 'wb') as f:
    pickle.dump(x, f)

# %%
# open the file in read and binary mode
with open(picklefile, 'rb') as f:
    p = pickle.load(f)
p
# Out:
# [1, 'simple', 'list']

# %% [markdown]
# # The `try` statement
# * "The `try` statement specifies exception handlers and/or cleanup code for a group of statements"
# * "The `except` clause(s) specify one or more exception handlers. When no exception occurs in the `try` clause, no exception handler is executed"`
# * "An expression-less `except` clause, if present, must be last; it matches any exception"
# * "The optional `else` clause is executed if the control flow leaves the `try` suite, no exception was raised, and no `return`, `continue`, or `break` statement was executed"
# * "If `finally` is present, it specifies a ‘cleanup’ handler"
#
# https://docs.python.org/3/reference/compound_stmts.html#the-try-statement

# %%
def f(x):
    try:
        print("Starting...")
        print("1/x={} with x={}".format(1/x, x))
        return x
    except ZeroDivisionError:
        print("ZeroDivisionError raised...")
    except Exception as e:
        print("Exception: {}".format(e))
    finally:
        print("Finishing up...")
f(1)
# Out:
# Starting...
# 1/x=1.0 with x=1
# Finishing up...
# 1

# %%
f(0)
# Out:
# Starting...
# ZeroDivisionError raised...
# Finishing up...

# %%
f('a')
# Out:
# Starting...
# Exception: unsupported operand type(s) for /: 'int' and 'str'
# Finishing up...

# %% [markdown]
# More exceptions are documented at https://docs.python.org/3/tutorial/errors.html#exceptions
